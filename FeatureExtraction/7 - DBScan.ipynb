# %% [markdown]
# # DBScan Cluster

# %% [markdown]
# ## Inputs:
# * Minimum number of members in a cluster ($minSamples$)
# * Maximum distance (similarity) between two members ($eps$)
# * Dataset
#
# ## Outputs
# * Cluster membership
#
# ## Process
#
#
#
# ## Intuition
#
#
#
# ## Downsides

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()  # for plot styling
import numpy as np

# Generate sample data and plot
from sklearn.datasets.samples_generator import make_blobs
X, y_true = make_blobs(n_samples=300, centers=4,
                       cluster_std=0.60, random_state=0)
plt.scatter(X[:, 0], X[:, 1], s=10);
# Out:
# /home/jbslanka/mypython/lib/python3.8/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.datasets.samples_generator module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.datasets. Anything that cannot be imported from sklearn.datasets is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
from sklearn.cluster import DBSCAN

dbScan = DBSCAN(min_samples = 5, eps = 0.5)
clusters = dbScan.fit_predict(X)


plt.scatter(X[:, 0], X[:, 1], c=clusters, s=10, cmap='tab20')

#print(clusters)

# %%
from sklearn.datasets import make_moons
from sklearn.cluster import KMeans

X, y = make_moons(200, noise=.05, random_state=0)
labels = KMeans(2, random_state=0).fit_predict(X)
plt.scatter(X[:, 0], X[:, 1], c=labels,
            s=50, cmap='viridis');

# %%
dbScan = DBSCAN(min_samples = 5, eps = 0.25)
clusters = dbScan.fit_predict(X)

plt.scatter(X[:, 0], X[:, 1], c=clusters, s=10, cmap='viridis')
