# %% [markdown]
# ## .632 Bootstrap
#
# Sampling with replacement
# 63.2% in training set, 36.8 in test.
#
# Simulation of randomly selecting elements to validate math formulas

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
# Sampling is done with replacement by default
samples = np.random.choice(1000, 1000)

# %%
print(samples)
# Out:
# [973 305 835 687 513 949 450 212 749 862 932 498 537 193 980 708 475  62
#   86 340 660 886 204 930 250 457 329 632 206 532 363 300 548 877 375 874
#  276 893 882 560 411 148 712 698 544  56 962 197 707 208  34 415 597 386
#  594  36 439 234 657 471 915 671  46 354  29 720  55 407 467 441  98 673
#  785 936 867 829 651 812 499 583 855 442 360 166 901 179 920 434 501 905
#   77 180 874 695 993 961 754 204 671 869 316 766  52 314 122 330 966 211
#  675 534 216 208  81 671 165 481 595 649 417 710 318 153 431  78 584 514
#   37 579 462 682 645  70 860 644  94 883 931  97 730 735 148 738 222 556
#  649 641 125 984 549 345 158 759 868 383 917 418 217 851 788 344  27 361
#  156  20 816 866  72   9 918 464 233  90 572 483 793 991  27 764 471 354
#  688 366 295 774 294 496 265 508 661 353  80 731 508 323 873  29 966 218
#  763 623  35 749 118 211 855 348 990 514 320 224 211 755  83 439 349 404
#  611 303 501 390 128 592 763 278 343 538   8 120  68 825 285 514 729 811
# ...

# %%
uniqueSamples=set(samples)

# %%
print(uniqueSamples)
# Out:
# {1, 3, 4, 5, 6, 7, 8, 9, 12, 13, 19, 20, 21, 22, 23, 24, 25, 27, 28, 29, 30, 33, 34, 35, 36, 37, 38, 42, 44, 46, 47, 51, 52, 54, 55, 56, 57, 61, 62, 64, 65, 66, 67, 68, 69, 70, 71, 72, 74, 77, 78, 80, 81, 83, 84, 85, 86, 87, 90, 93, 94, 96, 97, 98, 100, 103, 104, 105, 106, 109, 110, 112, 113, 114, 115, 117, 118, 119, 120, 121, 122, 124, 125, 126, 127, 128, 131, 132, 133, 134, 136, 137, 140, 141, 142, 147, 148, 149, 151, 153, 156, 158, 160, 162, 163, 165, 166, 167, 169, 170, 172, 174, 177, 178, 179, 180, 181, 182, 185, 192, 193, 194, 195, 197, 204, 205, 206, 208, 209, 210, 211, 212, 214, 215, 216, 217, 218, 219, 222, 224, 225, 226, 227, 228, 230, 231, 232, 233, 234, 237, 238, 239, 244, 245, 246, 248, 250, 253, 255, 256, 257, 263, 265, 268, 270, 271, 273, 274, 275, 276, 277, 278, 279, 281, 284, 285, 287, 289, 291, 292, 293, 294, 295, 298, 299, 300, 301, 302, 303, 305, 307, 309, 310, 313, 314, 316, 317, 318, 319, 320, 323, 326, 327, 329, 330, 333, 334, 335, 338, 339, 340, 341, 343, 344,
# ...

# %%
print(len(uniqueSamples))
# Out:
# 628

# %%
total = 0
iterations = 1000
for i in range(iterations):
    total = total + len(set(np.random.choice(1000, 1000)))

print (total/iterations)
# Out:
# 632.019
